# %% [markdown]
# ## 수정 전 코드

# %%
import requests
from bs4 import BeautifulSoup

def get_search_naver_blog(query, start_page=1, end_page=None):
    start = (start_page - 1) * 10 + 1
    url = f'https://search.naver.com/search.naver?where=post&query={query}&start={start}'
    r = requests.get(url)
    bs = BeautifulSoup(r.text, 'lxml')
    
    result = []
    
    if end_page is None:
        # 41-50 / 6,670건 --> 6670
        tot_counts = int(bs.select('span.title_num')[0].text.split('/')[-1].replace('건', '').replace(',','').strip())
        end_page = (tot_counts / 10)
        if tot_counts % 10 > 0:
            end_page += 1
        
        if end_page > 900:
            end_page = 900
            
    lis = bs.select('li.sh_blog_top')
    for li in lis:
        try:
            thumbnail = li.select('img')[0]['src']
            title = li.select('dl > dt > a')[0]
            summary = li.select('dl > dd.sh_blog_passage')[0].text
            title_link = title['href']
            title_text = title.text

            result.append((thumnail, title_text, title_link, summary))
        except:
            continue
            
    if start_page < end_page:
        start_page += 1
        # 재귀함수, 함수의 리턴값이 []이기 때문에 재귀호출하면 평탄화를 위해 extend
        result.extend(get_search_naver_blog(query, start_page=start_page, end_page=end_page))
        
    return result

results = get_search_naver_blog('파이썬강좌', start_page=1)
for result in results:
    print(result)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-9d69b3d067dc> in <module>
#      40     return result
#      41
# ---> 42 results = get_search_naver_blog('파이썬강좌', start_page=1)
#      43 for result in results:
#      44     print(result)
#
# <ipython-input-2-9d69b3d067dc> in get_search_naver_blog(query, start_page, end_page)
#      12     if end_page is None:
#      13         # 41-50 / 6,670건 --> 6670
# ---> 14         tot_counts = int(bs.select('span.title_num')[0].text.split('/')[-1].replace('건', '').replace(',','').strip())
#      15         end_page = (tot_counts / 10)
#      16         if tot_counts % 10 > 0:
#
# IndexError: list index out of range

# %% [markdown]
# ## 개정

# %%
'''
함수화 시키고 페이징 기능 추가
'''
import requests
from bs4 import BeautifulSoup

import json

def get_search_naver_blog(keyword, start_page, end_page=None):
    '''네이버 블로그 검색 함수
    Args:
        keyword (str): 검색어
        start_page (int): 현재 페이지
        end_page (int): 마지막 페이지
        
    Returns:
        list : 최종 결과 목록
    '''
    
    # 검색 URL 주소
    # 네이버 페이징 처리는 1페이지, 2페이지 이런식이 아니라
    # startpage= 로 1, 11, 21 이런식으로 시작게시물 수의 개념으로 봐야함
    # url = "https://search.naver.com/search.naver?where=post&sm=tab_nmr&query={}&nso=&start={}".format(keyword, start_page)

    # 2020-11-29 일 수정
    # 웹페이지를 호출하면 아래의 주소로 ajax 통신을 하여 결과를 받아온 후 결과를 렌더링 하는 형태로 변경됨.
    url = "https://s.search.naver.com/p/blog/search.naver?where=blog&sm=tab_pge&api_type=1&query={}&start={}".format(keyword, start_page)
    r = requests.get(url)

    # 받아온 결과에 total 이라는 문자열이 없으면 오류로 판단!!!
    if r.text.find('total":"') < 0:
        return []

    # 데이터는 {"total":"갯수", "html":"블로그결과태그"} 형태로 넘어오는데
    # 자바스크립와 파이썬의 이질성으로 dict 형태나 json 형태로 바로 가공이 되지 않아서
    # 그냥 문자열로 처리함.
    __find_string = 'total":"'      # 최종 갯수를 먼저 파악하기 위해 결과갯수 추출
    __result = r.text               # request.get() 으로 얻은 텍스트 데이터

    # 결과에서 HTML 태그를 분리해내기 위한 파싱
    __html = __result[__result.find("<"):-1]
    # 얻어온 결과는 자바스크립트로 동작하는 문자열이라 " 문자가 \" , ' 문자가 \' 로 되어있음 이를 파이썬에서 사용할 수 있게 제거
    __html = __html[:-4].replace('\"', "").replace("\\", "").strip()
    # total 문자열을 찾아서 원하는 갯수만 추출하기 위해서 파싱
    '''
    "total":"1234" 에서 1234값을 찾기위한 여정

    1. 문자열.찾기('total":"') 이라는 글자의 시작위치 찾음
    2. 시작위치에 total:":" 글자수만큼 더한곳이 실제 원하는 데이터의 위치임 "total":"1234" 에서 필요한건 1의 위치
    3. 문자열 슬라이싱은 [시작:종료] 임
    4. 시작위치는 total":" 위치 더하기 total":" 의 갯수만큼이 시작위치
    5. 종료 위치는 "total":"1234" 에서 4 뒤의 " 여야 하기 때문에 " 문자를 total":" 이후에 나타는 " 를 찾아야 함
    6. 5의 조건을 구현하면 문자열.찾기('"', 어디서부터)
    7. 6의 어디서부터가 문자열.찾기(대상) + 대상.길이 가 됨
    8. 아래의 코드는 이를 한줄로 작성한 코드임
    # 문자열[문자열.찾기(대상) + 대상.길이 : 문자열찾기('"', 문자열찾기(대상) + 대상.길이))]
    '''
    tot_count = int(__result[__result.find(__find_string) + len(__find_string):__result.find('"', __result.find(__find_string) + len(__find_string))])

    # lxml 파서를 사용해서 응답내용 BeautifulSoup 으로 변환하여 bs 에 저장
    bs = BeautifulSoup(__html, "lxml")
    
    # 최종 결과를 리턴할 리스트
    results = []

    if end_page is None:
        # 총게시물 갯수 / 10 을 int 형으로 하면 end_page 값을 알 수 있음
        end_page = int(tot_count / 10)
        if end_page > 50:
            end_page = 51

    for li in bs.select("li"):
        try:
            title = li.select("a.api_txt_lines")[0].text
            href = li.select("a.api_txt_lines")[0]["href"]
            summary = li.select("a.total_dsc > div.api_txt_lines")[0].text
            results.append((title, href, summary, ""))
        except:
            continue

    # 현재 페이지가 마지막 페이지보다 작으면 
    if start_page < end_page:
        # 현재 페이지에 + 10증가 후 
        start_page += 10
        # 함수 스스로 재호출(재귀함수) 후 결과를 현재 results(결과를 리턴할 리스트)에 확장(extend) 시킴
        results.extend(get_search_naver_blog(keyword, start_page, end_page))
    
    # 최종 결과 리스트 리턴
    return results


# 함수 호출
results = get_search_naver_blog("파이썬강좌", 1)

# 결과 출력
for r in results:
    print(r)
# Out:
# ('데이터 분석 파이썬 강좌 클룸에서 독학 해보자.', 'https://blog.naver.com/aiwositai?Redirect=Log&logNo=222198330769', "파이썬 강좌 제가 직접 수강을 해보도록 하겠습니다. '누구나 쉽게 따라 할 수 있는 파이썬 프로그래밍' 기초 강의는 무료로 진행됩니다. 해당 강좌를 통해 파이썬에... ", '')
# ('파이썬 강좌 - 2강#왜 파이썬인가?', 'https://blog.naver.com/nkj2001?Redirect=Log&logNo=221656737848', '이런 스타일이 파이썬의 강점인 가장 큰 부분이라고 생각합니다. Windows 파일 감시... 물론 강좌도 보고 공부도 하고 중요합니다만.. 대게 강좌만 보고 공부만 하고... ', '')
# ('파이썬 강좌 DAY 1 - 파이썬 개발환경 구축하기', 'https://blog.naver.com/juwon7163?Redirect=Log&logNo=222185804182', '이 강좌를 쓰고 있는 현재 파이썬의 최신버전은 3.9.1입니다. 지금부터 공식 홈페이지에서 파이썬을 다운로드 받아보겠습니다. 파이썬을 설치하기 위해 우선... ', '')
# ('파이썬 강좌 독학 공부를 클룸으로 시작해요', 'https://blog.naver.com/msh408?Redirect=Log&logNo=222237705582', 'Best 강좌 중 선택하여 더욱 심화된 학습까지 이어질 수 있다는 부분도 좋더라고요. 무료로 수강할 수 있는 2가지의 프로그래밍 강의 중에 파이썬 프로그래밍을... ', '')
# ('파이썬강좌 무조건들어야해요', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221533156590', '강좌는 파이썬 입문하시는 분들을 위해 제작되었구요 실습 형태로 강의가 진행되기 때문에 컴퓨터는 반드시 있어야 합니다~! 소개해드리는 파이썬강좌는 파이썬이... ', '')
# ('파이썬 강좌... ', 'https://blog.naver.com/hs7345570?Redirect=Log&logNo=222213148887', '프로그래밍 기초강좌 포스팅에서 컴퓨터의 메모리 공간은 제한적이라고... (자바, C언어 등 다른 프로그래밍 언어와 달리 파이썬은 담기는 값에 따라 메모리 그릇의... ', '')
# ('파이썬 인강 ☞ Python 기초 개념부터 배우기 초보자 특별 강좌', 'https://blog.naver.com/beta700?Redirect=Log&logNo=222091992623', '2강 파이썬 배우기 강좌에서는 프로그램 코딩을 위한 파이썬 설치 과정에 대해 배웁니다. 3~5번째 수업에서는 정수, 실수, 문자열 데이터 타입과 각종 연산자에 대해... ', '')
# ('파이썬 강좌 - 기초 교육 및 상담 안내', 'https://blog.naver.com/urmyver?Redirect=Log&logNo=221472307277', '꾸준히만 한다면 어렵게 느껴지더라도 기본적인 기능은 결국 다 수행할 수 있는 난이도가 파이썬 기초 강좌입니다. 오프라인 수업 평일반 & 주말반 수업으로 나누어서... ', '')
# ('파이썬강좌 이제는 필수!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222190085248', '파이썬 패키지!> 입니다! 아이티동스쿨에는 파이썬강좌 관련 다양한 패키지와 단가 상품들이 있네요 혹시나 패키지가 부담되시는 분들이 있다면 단가 강좌를 이용하는... ', '')
# ('파이썬도 공부하고... 교수의 파이썬 강좌 PY4E(Python for... ', 'https://blog.naver.com/annerheekim?Redirect=Log&logNo=222057935147', '제가 보기에 이 강좌로 파이썬 공부를 처음 시작하는 건 비효율적일 것 같고 파이썬 기본 내용을 한번 배운 후에 복습 삼아서 봐 보면 좋을 것 같아요. 기초 지식... ', '')
# ('파이썬강좌 코딩이 하고 싶다면 Python 부터', 'https://blog.naver.com/wogjsdk21?Redirect=Log&logNo=222069560633', '파이썬강좌를 찾아보셔야겠죠?? 사실 각각의 프로그램언어가 모두 장단점이 있다곤 하지만 파이썬만큼은 기초코딩용도로는 너무나도 좋으니까요 우선 Python강좌는... ', '')
# ('파이썬 프로그래밍 독학 5시간만에 기초완성 동영상 강좌', 'https://blog.naver.com/ahalinux?Redirect=Log&logNo=221999426572', '5시간만에 파이썬 기초완성하는 동영상 강좌입니다. 원래 30강으로... #코딩파이썬 #파이썬5시간 #파이썬 프로그래밍 #파이썬 강좌 #파이썬 기초... ', '')
# ('파이썬 기초강좌 P02[변수사용하기, 변수출력하기]', 'https://blog.naver.com/bogusjohann?Redirect=Log&logNo=222225528368', 'print(f"{a}파이썬 기초강좌") 이렇게 하시면 됩니다. 한번 출력해볼게요. 자 이제 변수에 문자열을 넣어볼게요 변수에 문자열을 넣기 위해선 큰 따옴표(" ")를... ', '')
# ('파이썬 강좌 이젠 인터넷 라이브로 들어요', 'https://blog.naver.com/2579dlsgh?Redirect=Log&logNo=222095536246', '무급휴직도 길어지고 해서 집에서 뒹굴면 뭐하나 하고 파이썬 강좌 듣는 중이에요.... 원래는 실강을 들어볼까 고민했는데 최종적으로 파이썬 강좌 인터넷으로 선택하게... ', '')
# ('블로그래퍼의 인프런 파이썬 강좌 소개', 'https://blog.naver.com/nkj2001?Redirect=Log&logNo=221659193643', '파이썬의 기초적인 이론 부터 실제 프로그램을 만드는 내용까지 중점을 둔 강좌입... 위 파이썬 강좌 소개는 블로그래퍼가 남박사로 활동하는 인프런에서 제공하는... ', '')
# ('파이썬 강좌 : Check list 안에 넣어야하는 교육과정', 'https://blog.naver.com/fbfkfk123?Redirect=Log&logNo=222071342729', '파이썬, 과연 이 교육은 왜 필수인지 그리고 어디에서 들어야 하는지 오늘 알려드리도록 할게요. 파이썬 강좌를 초보자분들이 많이 도전하는 이유는 초보자분들도... ', '')
# ('파이썬강좌 KG아이티뱅크 수업을 실시간 라이브 강의로?!', 'https://blog.naver.com/dongwoo2843?Redirect=Log&logNo=222110277963', '그러한 코딩교육, 코딩강좌에 있어서 가장 기본이 되는 것이 바로 파이썬 강좌랍니다! 자 그렇다면 파이썬기초 강좌 어디서 어떻게 공부할 수 있을까요? 주야쌤은... ', '')
# ('2020 파이썬 유료 온라인 강좌 정리', 'https://blog.naver.com/isakk001?Redirect=Log&logNo=222130309252', '러닝스푼즈 - 파이썬 머신러닝 포트폴리오 패키지 150,000원 https://online.learningspoons.com/courses/pythonportfolio/ & 앞서 설명한 파이썬 강좌와 달리 이 강좌는 취업을... ', '')
# ('프로그래밍 언어 파이썬강좌 4 문자열', 'https://blog.naver.com/hs7345570?Redirect=Log&logNo=222228361523', '예를들어 위와 같이 된다면 오류가 발생하게 됩니다. 문자열 반복 파이썬에서는 문자형 변수를 곱하기 연산자(*)로 반복할 수 있습니다.', '')
# ('파이썬 강의 ☞ 프로그래밍 초보자 특별강좌 기초 개념부터... ', 'https://blog.naver.com/beta700?Redirect=Log&logNo=221932162555', '4회 파이썬 배우기 강좌에서는 정수와 실수, 문자열 데이터 타입에 대해 소개합니다. 5~6회차 파이썬 교육 인강에서는 산술연산자와 관계연산자, 논리연산자에 대해... ', '')
# ('파이썬강좌 절대 어렵지 않아요!', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221465505171', 'ㅎㅎ 오늘 제가 소개해드릴 파이썬강좌는 가장 기초적인 내용을 담고있는 강좌인데요! 이 강좌만 들어도 파이썬의 기초적인 사용법에 대해서는 모두 배울 수 있으니... ', '')
# ('파이썬강좌 입문자들도 들어와!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222223945102', '주제는 파이썬강좌입니다! 여러분 파이썬이라는 프로그램 사용해보신적... 파이썬강좌 외에도 아이티동스쿨에는 프로그래밍 관련 하둡, C , JAVA 등 다양한 강좌들이... ', '')
# ('파이썬python기초,장고 인강 교육 강좌 소개 드려요.', 'https://blog.naver.com/hanikim3155?Redirect=Log&logNo=222232795246', '교육 강좌" 추천 드립니다. 소정의 포인트를 지급받음. http://www.alzio.co.kr/ #알지오 #알지오평생교육원 #파이썬 #파이썬강좌 #파워빌더강의 #파이썬기초 #파이썬인강... ', '')
# ('『파이썬 python 기초, 장고 인강 교육 강좌』에 대한... ', 'https://blog.naver.com/tkdan44?Redirect=Log&logNo=222183027651', '“다른 곳에서 배우지 못했던 내용을 IT전문강사들의 노하우를 담은 전문 강좌로... 알지오 파이썬 강좌는 파이썬 설치부터 시작하여 입문자 분들을 대상을 하고... ', '')
# ('[STEP] 파이썬 코딩 공부 꿀팁 무료 강좌 나도 할 수 있다!... ', 'https://blog.naver.com/cyc06330?Redirect=Log&logNo=222154228536', '무료 강좌를 담아보았어요! 제가 추천한 파이썬 강좌들이 어떠셨나요? 파이썬을 공부하러 가고싶지 않으신가요? 다음에도 좋은 강좌들 추천해드리겠습니다!... ', '')
# ('[파이썬 강좌] 파이썬 클래스 기초', 'https://blog.naver.com/nasu0210?Redirect=Log&logNo=221521762630', '[파이썬 강좌] 파이썬 클래스 기초 이번 시간에는 파이썬 클래스에 대하여 알아 보겠습니다. 파이썬 클래스에 대하여 설명한 책이나 관련 웹사이트 블로그등이... ', '')
# ('파이썬 강좌 : 온-오프라인에서 똑같이 공부하기', 'https://blog.naver.com/kikieh6025?Redirect=Log&logNo=222232967816', '파이썬 강좌 : 온-오프라인에서 똑같이 공부하기 파이썬 공부는 해야 하는데... 동일한 강좌 수강이 가능하여 시공간의 제약없이 공부할 수 있는 곳, KG아이티뱅크가... ', '')
# ('파이썬 강좌 - 6강#변수와 사용법', 'https://blog.naver.com/nkj2001?Redirect=Log&logNo=221659180232', 'Python 설치 시 기본 설치되는 Python IDLE 사용 #파이썬변수 와 사용법 변수는... - 파이썬의 내장 키워드들은 사용할 수 없다.(if, for, while, or, and, True, False... ', '')
# ('파이썬 강좌 IT뱅크 비대면교육 어때요?', 'https://blog.naver.com/dlwldud5554?Redirect=Log&logNo=222085589776', '파이썬 강좌 IT뱅크 비대면교육 어때요? 파이썬 배우기 어디서 어떻게 해야할 지 고민인가요? IT전문학원 IT뱅크의 비대면교육을 통해 파이썬 강좌 수강하는 건... ', '')
# ('파이썬강좌추천 혼자 공부하기에도 굿!', 'https://blog.naver.com/allnewk724?Redirect=Log&logNo=221525064112', "파이썬이 처음이시고, 기본적인 대목부터 챙기고 싶다면 저는 김정일 강사님의 파이썬강좌추천! '파이썬 프로그래밍 제대로 배우기' 시리즈를 통해 1-2개월 내에... ", '')
# ('파이썬강좌 코딩이 하고 싶다면 Python 부터', 'https://blog.naver.com/wogjsdk21?Redirect=Log&logNo=222069560633', '파이썬강좌를 찾아보셔야겠죠?? 사실 각각의 프로그램언어가 모두 장단점이 있다곤 하지만 파이썬만큼은 기초코딩용도로는 너무나도 좋으니까요 우선 Python강좌는... ', '')
# ('파이썬 프로그래밍 독학 5시간만에 기초완성 동영상 강좌', 'https://blog.naver.com/ahalinux?Redirect=Log&logNo=221999426572', '5시간만에 파이썬 기초완성하는 동영상 강좌입니다. 원래 30강으로... #코딩파이썬 #파이썬5시간 #파이썬 프로그래밍 #파이썬 강좌 #파이썬 기초... ', '')
# ('파이썬 기초강좌 P02[변수사용하기, 변수출력하기]', 'https://blog.naver.com/bogusjohann?Redirect=Log&logNo=222225528368', 'print(f"{a}파이썬 기초강좌") 이렇게 하시면 됩니다. 한번 출력해볼게요. 자 이제 변수에 문자열을 넣어볼게요 변수에 문자열을 넣기 위해선 큰 따옴표(" ")를... ', '')
# ('파이썬 강좌 이젠 인터넷 라이브로 들어요', 'https://blog.naver.com/2579dlsgh?Redirect=Log&logNo=222095536246', '무급휴직도 길어지고 해서 집에서 뒹굴면 뭐하나 하고 파이썬 강좌 듣는 중이에요.... 원래는 실강을 들어볼까 고민했는데 최종적으로 파이썬 강좌 인터넷으로 선택하게... ', '')
# ('블로그래퍼의 인프런 파이썬 강좌 소개', 'https://blog.naver.com/nkj2001?Redirect=Log&logNo=221659193643', '파이썬의 기초적인 이론 부터 실제 프로그램을 만드는 내용까지 중점을 둔 강좌입... 위 파이썬 강좌 소개는 블로그래퍼가 남박사로 활동하는 인프런에서 제공하는... ', '')
# ('파이썬 강좌 : Check list 안에 넣어야하는 교육과정', 'https://blog.naver.com/fbfkfk123?Redirect=Log&logNo=222071342729', '파이썬, 과연 이 교육은 왜 필수인지 그리고 어디에서 들어야 하는지 오늘 알려드리도록 할게요. 파이썬 강좌를 초보자분들이 많이 도전하는 이유는 초보자분들도... ', '')
# ('파이썬강좌 KG아이티뱅크 수업을 실시간 라이브 강의로?!', 'https://blog.naver.com/dongwoo2843?Redirect=Log&logNo=222110277963', '그러한 코딩교육, 코딩강좌에 있어서 가장 기본이 되는 것이 바로 파이썬 강좌랍니다! 자 그렇다면 파이썬기초 강좌 어디서 어떻게 공부할 수 있을까요? 주야쌤은... ', '')
# ('2020 파이썬 유료 온라인 강좌 정리', 'https://blog.naver.com/isakk001?Redirect=Log&logNo=222130309252', '러닝스푼즈 - 파이썬 머신러닝 포트폴리오 패키지 150,000원 https://online.learningspoons.com/courses/pythonportfolio/ & 앞서 설명한 파이썬 강좌와 달리 이 강좌는 취업을... ', '')
# ('프로그래밍 언어 파이썬강좌 4 문자열', 'https://blog.naver.com/hs7345570?Redirect=Log&logNo=222228361523', '예를들어 위와 같이 된다면 오류가 발생하게 됩니다. 문자열 반복 파이썬에서는 문자형 변수를 곱하기 연산자(*)로 반복할 수 있습니다.', '')
# ('파이썬 강의 ☞ 프로그래밍 초보자 특별강좌 기초 개념부터... ', 'https://blog.naver.com/beta700?Redirect=Log&logNo=221932162555', '4회 파이썬 배우기 강좌에서는 정수와 실수, 문자열 데이터 타입에 대해 소개합니다. 5~6회차 파이썬 교육 인강에서는 산술연산자와 관계연산자, 논리연산자에 대해... ', '')
# ('파이썬강좌 절대 어렵지 않아요!', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221465505171', 'ㅎㅎ 오늘 제가 소개해드릴 파이썬강좌는 가장 기초적인 내용을 담고있는 강좌인데요! 이 강좌만 들어도 파이썬의 기초적인 사용법에 대해서는 모두 배울 수 있으니... ', '')
# ('파이썬강좌 입문자들도 들어와!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222223945102', '주제는 파이썬강좌입니다! 여러분 파이썬이라는 프로그램 사용해보신적... 파이썬강좌 외에도 아이티동스쿨에는 프로그래밍 관련 하둡, C , JAVA 등 다양한 강좌들이... ', '')
# ('파이썬python기초,장고 인강 교육 강좌 소개 드려요.', 'https://blog.naver.com/hanikim3155?Redirect=Log&logNo=222232795246', '교육 강좌" 추천 드립니다. 소정의 포인트를 지급받음. http://www.alzio.co.kr/ #알지오 #알지오평생교육원 #파이썬 #파이썬강좌 #파워빌더강의 #파이썬기초 #파이썬인강... ', '')
# ('『파이썬 python 기초, 장고 인강 교육 강좌』에 대한... ', 'https://blog.naver.com/tkdan44?Redirect=Log&logNo=222183027651', '“다른 곳에서 배우지 못했던 내용을 IT전문강사들의 노하우를 담은 전문 강좌로... 알지오 파이썬 강좌는 파이썬 설치부터 시작하여 입문자 분들을 대상을 하고... ', '')
# ('[STEP] 파이썬 코딩 공부 꿀팁 무료 강좌 나도 할 수 있다!... ', 'https://blog.naver.com/cyc06330?Redirect=Log&logNo=222154228536', '무료 강좌를 담아보았어요! 제가 추천한 파이썬 강좌들이 어떠셨나요? 파이썬을 공부하러 가고싶지 않으신가요? 다음에도 좋은 강좌들 추천해드리겠습니다!... ', '')
# ('[파이썬 강좌] 파이썬 클래스 기초', 'https://blog.naver.com/nasu0210?Redirect=Log&logNo=221521762630', '[파이썬 강좌] 파이썬 클래스 기초 이번 시간에는 파이썬 클래스에 대하여 알아 보겠습니다. 파이썬 클래스에 대하여 설명한 책이나 관련 웹사이트 블로그등이... ', '')
# ('파이썬 강좌 : 온-오프라인에서 똑같이 공부하기', 'https://blog.naver.com/kikieh6025?Redirect=Log&logNo=222232967816', '파이썬 강좌 : 온-오프라인에서 똑같이 공부하기 파이썬 공부는 해야 하는데... 동일한 강좌 수강이 가능하여 시공간의 제약없이 공부할 수 있는 곳, KG아이티뱅크가... ', '')
# ('파이썬 강좌 - 6강#변수와 사용법', 'https://blog.naver.com/nkj2001?Redirect=Log&logNo=221659180232', 'Python 설치 시 기본 설치되는 Python IDLE 사용 #파이썬변수 와 사용법 변수는... - 파이썬의 내장 키워드들은 사용할 수 없다.(if, for, while, or, and, True, False... ', '')
# ('파이썬 강좌 IT뱅크 비대면교육 어때요?', 'https://blog.naver.com/dlwldud5554?Redirect=Log&logNo=222085589776', '파이썬 강좌 IT뱅크 비대면교육 어때요? 파이썬 배우기 어디서 어떻게 해야할 지 고민인가요? IT전문학원 IT뱅크의 비대면교육을 통해 파이썬 강좌 수강하는 건... ', '')
# ('파이썬강좌추천 혼자 공부하기에도 굿!', 'https://blog.naver.com/allnewk724?Redirect=Log&logNo=221525064112', "파이썬이 처음이시고, 기본적인 대목부터 챙기고 싶다면 저는 김정일 강사님의 파이썬강좌추천! '파이썬 프로그래밍 제대로 배우기' 시리즈를 통해 1-2개월 내에... ", '')
# ("프로그래밍언어 '파이썬' 강좌 3. 변수... ", 'https://blog.naver.com/hs7345570?Redirect=Log&logNo=222226041153', "파이썬 강좌 첫 포스팅에서 '='기호에 대해서 알아봤었습니다. 파이썬에서 '='기호는 일반 수학과는 조금 다르게 오른쪽값을 왼쪽으로 넣어준다는 의미라 했죠? 굉장히... ", '')
# ('파이썬 ☞ Python 초보자 특별강좌 기초 개념부터 배우기', 'https://blog.naver.com/beta700?Redirect=Log&logNo=221715118460', '파이썬 강좌 12강에서는 무한 루프 작성방법과 break 문에 대해 설명합니다. 13회 파이썬 배우기 동영상 강좌에서는 중첩 for loop 작동 방법에 대해 수업합니다.', '')
# ('[에듀얍] 컴퓨터 자격증 인강 추천 : 파이썬 강좌부터 어도비... ', 'https://blog.naver.com/llnallll?Redirect=Log&logNo=221532731954', 'w프리미엄 1년 과정으로 370일에 89,000원 Eduyap에서는 신규강좌 #파이썬강좌 까지 들을 수 있어요 ^^ 내가 듣고 싶은 #어도비크리에이티브마스터과정 그중에서... ', '')
# ('파이썬강좌 이거 듣고 마스터했어요', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221651623296', '저는 파이썬강좌로 "파이썬 패키지"를 추천드려요! 왜냐하면 180일의 넉넉한 수강기간동안 파이썬 초보자분들도 넉넉하게 공부하실 수 있기 때문이죠 게다가 긴... ', '')
# ('파이썬강좌 이렇게 들어봐!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222127720105', 'ㅎㅎ 제가 추천드리고싶은 파이썬강좌는 바로 [특별할인] 파이썬 패키지! 인데요! 패키지 강좌이기 때문에 기초부터 실무 강의까지 모두 포함되어 있습니다! 수강기간은... ', '')
# ('파이썬 기초강좌 P01[print 사용]', 'https://blog.naver.com/bogusjohann?Redirect=Log&logNo=222224706301', '이렇게 Hello, word 1234가 잘 출력되는 것을 보실수 있으십니다. 밑에 나오는 것은 별로 상관 않쓰셔도 됩니다. 자그럼 파이썬 기초강좌 P01[print사용]을 마치겠습니다.', '')
# ('파이썬 강좌 for 인공지능 기초', 'https://blog.naver.com/kyh941031?Redirect=Log&logNo=222090047539', '(X) 파이썬문법 + Numpy + Pandas + Matplotlib (O) - 연사: KAIST 기술경영학부... 18 기초지식이 없는 사람들이 인공지능 공부를 위해선 우선 파이썬 공부가... ', '')
# ('파이썬 강좌 1 ) for 반복문', 'https://blog.naver.com/puleugo2?Redirect=Log&logNo=222234169063', '여러곳에서 파이썬을 프로그래밍을 처음 접할때 추천하는 언어로 추천합니다. 이 글을 초보자분들이 많이 읽을것이라 생각하여, 최대한 쉽게 글을 써봅니다. 저도... ', '')
# ('[파이썬 강좌]1.왜 파이썬을 배워야 하는가?', 'https://blog.naver.com/jamsuham75?Redirect=Log&logNo=222223794950', "제가 집필한 '나혼자 파이썬'을 기반으로 동영상 강좌를 시작하였습니다. 매일 한 섹션씩 업로드하는 것이 목표입니다. 잘 될지는 모르겠지만 열심히... ", '')
# ('파이썬 기초 요약 30분 강좌(1)', 'https://blog.naver.com/annerheekim?Redirect=Log&logNo=222050024326', '이 30분 강좌에서 다루는 내용은 제가 주피터로 직접 실습하면서 입력한 것이 있으니 참고하시고 괜찮다 싶으면 파이썬에 관심이 있으신 분들은 한번 들어 보셔도... ', '')
# ('파이썬강좌 절대 어렵지 않아요!', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221465505171', 'ㅎㅎ 오늘 제가 소개해드릴 파이썬강좌는 가장 기초적인 내용을 담고있는 강좌인데요! 이 강좌만 들어도 파이썬의 기초적인 사용법에 대해서는 모두 배울 수 있으니... ', '')
# ('파이썬강좌 입문자들도 들어와!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222223945102', '주제는 파이썬강좌입니다! 여러분 파이썬이라는 프로그램 사용해보신적... 파이썬강좌 외에도 아이티동스쿨에는 프로그래밍 관련 하둡, C , JAVA 등 다양한 강좌들이... ', '')
# ('파이썬python기초,장고 인강 교육 강좌 소개 드려요.', 'https://blog.naver.com/hanikim3155?Redirect=Log&logNo=222232795246', '교육 강좌" 추천 드립니다. 소정의 포인트를 지급받음. http://www.alzio.co.kr/ #알지오 #알지오평생교육원 #파이썬 #파이썬강좌 #파워빌더강의 #파이썬기초 #파이썬인강... ', '')
# ('『파이썬 python 기초, 장고 인강 교육 강좌』에 대한... ', 'https://blog.naver.com/tkdan44?Redirect=Log&logNo=222183027651', '“다른 곳에서 배우지 못했던 내용을 IT전문강사들의 노하우를 담은 전문 강좌로... 알지오 파이썬 강좌는 파이썬 설치부터 시작하여 입문자 분들을 대상을 하고... ', '')
# ('[STEP] 파이썬 코딩 공부 꿀팁 무료 강좌 나도 할 수 있다!... ', 'https://blog.naver.com/cyc06330?Redirect=Log&logNo=222154228536', '무료 강좌를 담아보았어요! 제가 추천한 파이썬 강좌들이 어떠셨나요? 파이썬을 공부하러 가고싶지 않으신가요? 다음에도 좋은 강좌들 추천해드리겠습니다!... ', '')
# ('[파이썬 강좌] 파이썬 클래스 기초', 'https://blog.naver.com/nasu0210?Redirect=Log&logNo=221521762630', '[파이썬 강좌] 파이썬 클래스 기초 이번 시간에는 파이썬 클래스에 대하여 알아 보겠습니다. 파이썬 클래스에 대하여 설명한 책이나 관련 웹사이트 블로그등이... ', '')
# ('파이썬 강좌 : 온-오프라인에서 똑같이 공부하기', 'https://blog.naver.com/kikieh6025?Redirect=Log&logNo=222232967816', '파이썬 강좌 : 온-오프라인에서 똑같이 공부하기 파이썬 공부는 해야 하는데... 동일한 강좌 수강이 가능하여 시공간의 제약없이 공부할 수 있는 곳, KG아이티뱅크가... ', '')
# ('파이썬 강좌 - 6강#변수와 사용법', 'https://blog.naver.com/nkj2001?Redirect=Log&logNo=221659180232', 'Python 설치 시 기본 설치되는 Python IDLE 사용 #파이썬변수 와 사용법 변수는... - 파이썬의 내장 키워드들은 사용할 수 없다.(if, for, while, or, and, True, False... ', '')
# ('파이썬 강좌 IT뱅크 비대면교육 어때요?', 'https://blog.naver.com/dlwldud5554?Redirect=Log&logNo=222085589776', '파이썬 강좌 IT뱅크 비대면교육 어때요? 파이썬 배우기 어디서 어떻게 해야할 지 고민인가요? IT전문학원 IT뱅크의 비대면교육을 통해 파이썬 강좌 수강하는 건... ', '')
# ('파이썬강좌추천 혼자 공부하기에도 굿!', 'https://blog.naver.com/allnewk724?Redirect=Log&logNo=221525064112', "파이썬이 처음이시고, 기본적인 대목부터 챙기고 싶다면 저는 김정일 강사님의 파이썬강좌추천! '파이썬 프로그래밍 제대로 배우기' 시리즈를 통해 1-2개월 내에... ", '')
# ("프로그래밍언어 '파이썬' 강좌 3. 변수... ", 'https://blog.naver.com/hs7345570?Redirect=Log&logNo=222226041153', "파이썬 강좌 첫 포스팅에서 '='기호에 대해서 알아봤었습니다. 파이썬에서 '='기호는 일반 수학과는 조금 다르게 오른쪽값을 왼쪽으로 넣어준다는 의미라 했죠? 굉장히... ", '')
# ('파이썬 ☞ Python 초보자 특별강좌 기초 개념부터 배우기', 'https://blog.naver.com/beta700?Redirect=Log&logNo=221715118460', '파이썬 강좌 12강에서는 무한 루프 작성방법과 break 문에 대해 설명합니다. 13회 파이썬 배우기 동영상 강좌에서는 중첩 for loop 작동 방법에 대해 수업합니다.', '')
# ('[에듀얍] 컴퓨터 자격증 인강 추천 : 파이썬 강좌부터 어도비... ', 'https://blog.naver.com/llnallll?Redirect=Log&logNo=221532731954', 'w프리미엄 1년 과정으로 370일에 89,000원 Eduyap에서는 신규강좌 #파이썬강좌 까지 들을 수 있어요 ^^ 내가 듣고 싶은 #어도비크리에이티브마스터과정 그중에서... ', '')
# ('파이썬강좌 이거 듣고 마스터했어요', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221651623296', '저는 파이썬강좌로 "파이썬 패키지"를 추천드려요! 왜냐하면 180일의 넉넉한 수강기간동안 파이썬 초보자분들도 넉넉하게 공부하실 수 있기 때문이죠 게다가 긴... ', '')
# ('파이썬강좌 이렇게 들어봐!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222127720105', 'ㅎㅎ 제가 추천드리고싶은 파이썬강좌는 바로 [특별할인] 파이썬 패키지! 인데요! 패키지 강좌이기 때문에 기초부터 실무 강의까지 모두 포함되어 있습니다! 수강기간은... ', '')
# ('파이썬 기초강좌 P01[print 사용]', 'https://blog.naver.com/bogusjohann?Redirect=Log&logNo=222224706301', '이렇게 Hello, word 1234가 잘 출력되는 것을 보실수 있으십니다. 밑에 나오는 것은 별로 상관 않쓰셔도 됩니다. 자그럼 파이썬 기초강좌 P01[print사용]을 마치겠습니다.', '')
# ('파이썬 강좌 for 인공지능 기초', 'https://blog.naver.com/kyh941031?Redirect=Log&logNo=222090047539', '(X) 파이썬문법 + Numpy + Pandas + Matplotlib (O) - 연사: KAIST 기술경영학부... 18 기초지식이 없는 사람들이 인공지능 공부를 위해선 우선 파이썬 공부가... ', '')
# ('파이썬 강좌 1 ) for 반복문', 'https://blog.naver.com/puleugo2?Redirect=Log&logNo=222234169063', '여러곳에서 파이썬을 프로그래밍을 처음 접할때 추천하는 언어로 추천합니다. 이 글을 초보자분들이 많이 읽을것이라 생각하여, 최대한 쉽게 글을 써봅니다. 저도... ', '')
# ('[파이썬 강좌]1.왜 파이썬을 배워야 하는가?', 'https://blog.naver.com/jamsuham75?Redirect=Log&logNo=222223794950', "제가 집필한 '나혼자 파이썬'을 기반으로 동영상 강좌를 시작하였습니다. 매일 한 섹션씩 업로드하는 것이 목표입니다. 잘 될지는 모르겠지만 열심히... ", '')
# ('파이썬 기초 요약 30분 강좌(1)', 'https://blog.naver.com/annerheekim?Redirect=Log&logNo=222050024326', '이 30분 강좌에서 다루는 내용은 제가 주피터로 직접 실습하면서 입력한 것이 있으니 참고하시고 괜찮다 싶으면 파이썬에 관심이 있으신 분들은 한번 들어 보셔도... ', '')
# ('Udemy의 파이썬 강좌', 'https://blog.naver.com/choiyon111?Redirect=Log&logNo=222105187390', 'Udemy 파이썬 강좌입니다. 유튜브를 보고 이리저리 생각하고 살피던 중 Udemy 강좌를... 조금씩 파이썬에 대한 이해를 넓혀 갈 수 있을 것 같습니다. 최근 3일 동안은 계속... ', '')
# ('[거꾸로학습] 파이썬 강좌 참여', 'https://blog.naver.com/gudhand?Redirect=Log&logNo=222117430652', '(동영상강좌 및 교재와 실습문제, 진도관리) - 학습자간 소통 : Slack(메신저) - 출석 및 학습관리 : Notion - 파이썬 개발 환경 6. 개별 학습내용 및 적용사례의 기록... ', '')
# ('파이썬강좌 초보자도 정말 쉽게!', 'https://blog.naver.com/allnewk724?Redirect=Log&logNo=221614280169', '전문강사님께서 강좌를 진행해야하는 것도 무시할 수 없을텐데요. 그런 파이썬강좌를 들어볼 수 있는 곳들 가운데 아이티동스쿨 사이트도 있었습니다. 파이썬을 비롯해... ', '')
# ('파이썬 강의 ☞ 프로그래밍 기초 개념부터 배우기 강좌', 'https://blog.naver.com/beta700?Redirect=Log&logNo=222178974570', '2회차 파이썬 배우기 강좌에서는 프로그램 설치 방법에 대해 알아봅니다. 3~4번째 수업에서는 정수, 실수, 문자열 데이터 타입과 변수의 개념에 대해 학습합니다. 5... ', '')
# ('파이썬 기초 강의 목록 | python 강좌 유튜브', 'https://blog.naver.com/ohgnus56?Redirect=Log&logNo=221520249037', '출처 : 유튜브 김플 스튜디오 <파이썬 문자열(string)> 파이썬 문자열 포맷팅 기초 강좌 파이썬 print 함수 줄바꿈 제거 출력 파이썬 문자열 변환 수정 삭제... ', '')
# ('파이썬으로 게임만들기 -<파이썬무료강좌>', 'https://blog.naver.com/pinksoya?Redirect=Log&logNo=222177844728', '여름부터 해보고 싶었는데 못해본 파이썬으로 게임만들기를 해보았어요! 요런 게임을 만드는 강좌였는데 3시간이면 만든다는데.... pygame 을 처음 사용해보는 저는... ', '')
# ('파이썬강좌 이걸로 확실히!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222154953233', "싶은 파이썬강좌는 바로 '[특별할인] 파이썬 패키지' 입니다!! 패키지 강좌이기 때문에 기초부터 실무 강의까지 모두 포함되어 있습니다! 수강기간은 180일 수강료는 79... ", '')
# ('왕초보 파이썬 강좌 1.3 변수', 'https://blog.naver.com/estar009?Redirect=Log&logNo=222064971110', '또다시 이 왕초보 파이썬 강좌로 몇시간만에 돌아왔네요. 이번에 배울 것은... 재밌으신가요? 맞습니다. 프로그래밍은 재밌습니다. 오늘의 강좌는 여기까지. 그럼 스-바!', '')
# ('Stein 의 초보를 위한 파이썬 ( Python ) < 실전 강좌 > - 제 0... ', 'https://blog.naver.com/henry9487?Redirect=Log&logNo=221988309617', '제 블로그에서 파이썬 기본기 강좌를 잘 보고 계신가요 ? 파이썬 강좌 프로젝트를 시작한지 얼마 되지 않았지만, 많은 사람들이 찾아와서 봐주시네요. 정말 감사합니다.... ', '')
# ('[파이썬 강좌]데이터베이스 sqlite 테이블생성', 'https://blog.naver.com/nasu0210?Redirect=Log&logNo=221526337232', '[파이썬 강좌]데이터베이스 sqlite 테이블생성 파이썬으로 데이터베이스를 다루어 보겠습니다. 파이썬으로 여러종류의 데이터 베이스(오라클... ', '')
# ("프로그래밍언어 '파이썬' 강좌 3. 변수... ", 'https://blog.naver.com/hs7345570?Redirect=Log&logNo=222226041153', "파이썬 강좌 첫 포스팅에서 '='기호에 대해서 알아봤었습니다. 파이썬에서 '='기호는 일반 수학과는 조금 다르게 오른쪽값을 왼쪽으로 넣어준다는 의미라 했죠? 굉장히... ", '')
# ('파이썬 ☞ Python 초보자 특별강좌 기초 개념부터 배우기', 'https://blog.naver.com/beta700?Redirect=Log&logNo=221715118460', '파이썬 강좌 12강에서는 무한 루프 작성방법과 break 문에 대해 설명합니다. 13회 파이썬 배우기 동영상 강좌에서는 중첩 for loop 작동 방법에 대해 수업합니다.', '')
# ('[에듀얍] 컴퓨터 자격증 인강 추천 : 파이썬 강좌부터 어도비... ', 'https://blog.naver.com/llnallll?Redirect=Log&logNo=221532731954', 'w프리미엄 1년 과정으로 370일에 89,000원 Eduyap에서는 신규강좌 #파이썬강좌 까지 들을 수 있어요 ^^ 내가 듣고 싶은 #어도비크리에이티브마스터과정 그중에서... ', '')
# ('파이썬강좌 이거 듣고 마스터했어요', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221651623296', '저는 파이썬강좌로 "파이썬 패키지"를 추천드려요! 왜냐하면 180일의 넉넉한 수강기간동안 파이썬 초보자분들도 넉넉하게 공부하실 수 있기 때문이죠 게다가 긴... ', '')
# ('파이썬강좌 이렇게 들어봐!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222127720105', 'ㅎㅎ 제가 추천드리고싶은 파이썬강좌는 바로 [특별할인] 파이썬 패키지! 인데요! 패키지 강좌이기 때문에 기초부터 실무 강의까지 모두 포함되어 있습니다! 수강기간은... ', '')
# ('파이썬 기초강좌 P01[print 사용]', 'https://blog.naver.com/bogusjohann?Redirect=Log&logNo=222224706301', '이렇게 Hello, word 1234가 잘 출력되는 것을 보실수 있으십니다. 밑에 나오는 것은 별로 상관 않쓰셔도 됩니다. 자그럼 파이썬 기초강좌 P01[print사용]을 마치겠습니다.', '')
# ('파이썬 강좌 for 인공지능 기초', 'https://blog.naver.com/kyh941031?Redirect=Log&logNo=222090047539', '(X) 파이썬문법 + Numpy + Pandas + Matplotlib (O) - 연사: KAIST 기술경영학부... 18 기초지식이 없는 사람들이 인공지능 공부를 위해선 우선 파이썬 공부가... ', '')
# ('파이썬 강좌 1 ) for 반복문', 'https://blog.naver.com/puleugo2?Redirect=Log&logNo=222234169063', '여러곳에서 파이썬을 프로그래밍을 처음 접할때 추천하는 언어로 추천합니다. 이 글을 초보자분들이 많이 읽을것이라 생각하여, 최대한 쉽게 글을 써봅니다. 저도... ', '')
# ('[파이썬 강좌]1.왜 파이썬을 배워야 하는가?', 'https://blog.naver.com/jamsuham75?Redirect=Log&logNo=222223794950', "제가 집필한 '나혼자 파이썬'을 기반으로 동영상 강좌를 시작하였습니다. 매일 한 섹션씩 업로드하는 것이 목표입니다. 잘 될지는 모르겠지만 열심히... ", '')
# ('파이썬 기초 요약 30분 강좌(1)', 'https://blog.naver.com/annerheekim?Redirect=Log&logNo=222050024326', '이 30분 강좌에서 다루는 내용은 제가 주피터로 직접 실습하면서 입력한 것이 있으니 참고하시고 괜찮다 싶으면 파이썬에 관심이 있으신 분들은 한번 들어 보셔도... ', '')
# ('Udemy의 파이썬 강좌', 'https://blog.naver.com/choiyon111?Redirect=Log&logNo=222105187390', 'Udemy 파이썬 강좌입니다. 유튜브를 보고 이리저리 생각하고 살피던 중 Udemy 강좌를... 조금씩 파이썬에 대한 이해를 넓혀 갈 수 있을 것 같습니다. 최근 3일 동안은 계속... ', '')
# ('[거꾸로학습] 파이썬 강좌 참여', 'https://blog.naver.com/gudhand?Redirect=Log&logNo=222117430652', '(동영상강좌 및 교재와 실습문제, 진도관리) - 학습자간 소통 : Slack(메신저) - 출석 및 학습관리 : Notion - 파이썬 개발 환경 6. 개별 학습내용 및 적용사례의 기록... ', '')
# ('파이썬강좌 초보자도 정말 쉽게!', 'https://blog.naver.com/allnewk724?Redirect=Log&logNo=221614280169', '전문강사님께서 강좌를 진행해야하는 것도 무시할 수 없을텐데요. 그런 파이썬강좌를 들어볼 수 있는 곳들 가운데 아이티동스쿨 사이트도 있었습니다. 파이썬을 비롯해... ', '')
# ('파이썬 강의 ☞ 프로그래밍 기초 개념부터 배우기 강좌', 'https://blog.naver.com/beta700?Redirect=Log&logNo=222178974570', '2회차 파이썬 배우기 강좌에서는 프로그램 설치 방법에 대해 알아봅니다. 3~4번째 수업에서는 정수, 실수, 문자열 데이터 타입과 변수의 개념에 대해 학습합니다. 5... ', '')
# ('파이썬 기초 강의 목록 | python 강좌 유튜브', 'https://blog.naver.com/ohgnus56?Redirect=Log&logNo=221520249037', '출처 : 유튜브 김플 스튜디오 <파이썬 문자열(string)> 파이썬 문자열 포맷팅 기초 강좌 파이썬 print 함수 줄바꿈 제거 출력 파이썬 문자열 변환 수정 삭제... ', '')
# ('파이썬으로 게임만들기 -<파이썬무료강좌>', 'https://blog.naver.com/pinksoya?Redirect=Log&logNo=222177844728', '여름부터 해보고 싶었는데 못해본 파이썬으로 게임만들기를 해보았어요! 요런 게임을 만드는 강좌였는데 3시간이면 만든다는데.... pygame 을 처음 사용해보는 저는... ', '')
# ('파이썬강좌 이걸로 확실히!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222154953233', "싶은 파이썬강좌는 바로 '[특별할인] 파이썬 패키지' 입니다!! 패키지 강좌이기 때문에 기초부터 실무 강의까지 모두 포함되어 있습니다! 수강기간은 180일 수강료는 79... ", '')
# ('왕초보 파이썬 강좌 1.3 변수', 'https://blog.naver.com/estar009?Redirect=Log&logNo=222064971110', '또다시 이 왕초보 파이썬 강좌로 몇시간만에 돌아왔네요. 이번에 배울 것은... 재밌으신가요? 맞습니다. 프로그래밍은 재밌습니다. 오늘의 강좌는 여기까지. 그럼 스-바!', '')
# ('Stein 의 초보를 위한 파이썬 ( Python ) < 실전 강좌 > - 제 0... ', 'https://blog.naver.com/henry9487?Redirect=Log&logNo=221988309617', '제 블로그에서 파이썬 기본기 강좌를 잘 보고 계신가요 ? 파이썬 강좌 프로젝트를 시작한지 얼마 되지 않았지만, 많은 사람들이 찾아와서 봐주시네요. 정말 감사합니다.... ', '')
# ('[파이썬 강좌]데이터베이스 sqlite 테이블생성', 'https://blog.naver.com/nasu0210?Redirect=Log&logNo=221526337232', '[파이썬 강좌]데이터베이스 sqlite 테이블생성 파이썬으로 데이터베이스를 다루어 보겠습니다. 파이썬으로 여러종류의 데이터 베이스(오라클... ', '')
# ('파이썬 강좌 4 ) 변수', 'https://blog.naver.com/puleugo2?Redirect=Log&logNo=222238005540', 'A = 100 파이썬에서는 변수를 아주 쉽게 지정할 수 있습니다. 앞에서 수가 아닌... 많은 곳에도 사용할 수 있습니다. 다른 사용처는 다음 강좌에서 깊게 들어가겠습니다.', '')
# ("edwith 강좌 '모두를 위한 프로그래밍 : 파이썬을 이용한... ", 'https://blog.naver.com/dkrkvudghk?Redirect=Log&logNo=222094115845', '이 강좌에서 인상깊었던 것은 파이썬에도 클래스 개념이 있었다는 것이다. C... 공부해서 사용해봐야겠다. 모두를 위한 파이썬 강좌 중에 제일 보람찼던 강좌였다.', '')
# ('파이썬 강좌 - 파이썬(python) 시작', 'https://blog.naver.com/ahalinux?Redirect=Log&logNo=221390492962', '아래 동영상을 링크합니다. 천천히 보면서 준비해 보세요. 파이썬(python) 강좌 ① - 인강 안내 - 오리엔테이션 - 양주종의 코딩스쿨 즐겁게 공부하세요.', '')
# ('파이썬 강좌 번외편. 클로저(Closure)', 'https://exynoa.tistory.com/347', '다시 살펴보는 스코핑 룰(Scoping rule) 파이썬의 함수 강좌 에서 스코핑 룰을 살펴본 적이 있습니다. 이 강좌에서는 혼란을 피하기 위해 LGB... ', '')
# ('파이썬 인강 ☞ 데이터 분석을... 통계분석 데이터 기초 과정 강좌', 'https://blog.naver.com/beta700?Redirect=Log&logNo=221788408728', '2회차 파이썬 배우기 강좌에서는 아나콘다 설치방법에 대해 학습합니다. 3~4회에서는 통합개발툴 spyder와 jupyter notebook 기본 사용법에 대해 배웁니다. 5~8번째... ', '')
# ('파이썬강좌 겁내지말고 시작하세요!', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221433148776', '개설되어있어요 파이썬으로 입문을 한뒤에 자바나 C언어, PHP 같은 언어도 추가적으로 공부하기에도 좋은 사이트 입니다. 파이썬강좌만 묶어놓은 패키지강좌 입니다.... ', '')
# ('파이썬강좌 하나도 어렵지 않다!', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221388707896', '언제 어디서나, 시간이나 장소에 제약 없이 들을 수 있는 온라인 파이썬강좌와 함께라면 누구나 파이썬 정복이 가능하답니다! 파이썬의 기초부터 응용까지 한번에... ', '')
# ('파이썬강좌 알차게 들어봐요!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222096179423', '저는 [특별할인] 파이썬 패키지! 강좌를 추천 드려요~!! 패키지 파이썬강좌로 기초부터 실무 강의까지 포함되어 있습니다 수강기간은 180일이고 가격은 79,000원으로... ', '')
# ('파이썬강좌 어디에 있지?', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221411163547', '아이티동스쿨에서 인기강좌 베스트 5를 보니 1위부터 5위까지 파이썬으로... 저는 hit라고 써져있는 가장 인기있는 파이썬강좌를 선택했어요. Python(파이썬) 프로그래밍... ', '')
# ('파이썬(Python) 강좌 00 - Prologue', 'https://blog.naver.com/msj5826?Redirect=Log&logNo=221008309705', '일부로 파이썬 버전 2를 사용하는 곳도 있습니다. 이번 파이썬 강좌는 여기서 마치고 다음강좌는 파이썬을 설치하고 실행하는 방법에 대해 알아보도록 하겠습니다.', '')
# ('Udemy의 파이썬 강좌', 'https://blog.naver.com/choiyon111?Redirect=Log&logNo=222105187390', 'Udemy 파이썬 강좌입니다. 유튜브를 보고 이리저리 생각하고 살피던 중 Udemy 강좌를... 조금씩 파이썬에 대한 이해를 넓혀 갈 수 있을 것 같습니다. 최근 3일 동안은 계속... ', '')
# ('[거꾸로학습] 파이썬 강좌 참여', 'https://blog.naver.com/gudhand?Redirect=Log&logNo=222117430652', '(동영상강좌 및 교재와 실습문제, 진도관리) - 학습자간 소통 : Slack(메신저) - 출석 및 학습관리 : Notion - 파이썬 개발 환경 6. 개별 학습내용 및 적용사례의 기록... ', '')
# ('파이썬강좌 초보자도 정말 쉽게!', 'https://blog.naver.com/allnewk724?Redirect=Log&logNo=221614280169', '전문강사님께서 강좌를 진행해야하는 것도 무시할 수 없을텐데요. 그런 파이썬강좌를 들어볼 수 있는 곳들 가운데 아이티동스쿨 사이트도 있었습니다. 파이썬을 비롯해... ', '')
# ('파이썬 강의 ☞ 프로그래밍 기초 개념부터 배우기 강좌', 'https://blog.naver.com/beta700?Redirect=Log&logNo=222178974570', '2회차 파이썬 배우기 강좌에서는 프로그램 설치 방법에 대해 알아봅니다. 3~4번째 수업에서는 정수, 실수, 문자열 데이터 타입과 변수의 개념에 대해 학습합니다. 5... ', '')
# ('파이썬 기초 강의 목록 | python 강좌 유튜브', 'https://blog.naver.com/ohgnus56?Redirect=Log&logNo=221520249037', '출처 : 유튜브 김플 스튜디오 <파이썬 문자열(string)> 파이썬 문자열 포맷팅 기초 강좌 파이썬 print 함수 줄바꿈 제거 출력 파이썬 문자열 변환 수정 삭제... ', '')
# ('파이썬으로 게임만들기 -<파이썬무료강좌>', 'https://blog.naver.com/pinksoya?Redirect=Log&logNo=222177844728', '여름부터 해보고 싶었는데 못해본 파이썬으로 게임만들기를 해보았어요! 요런 게임을 만드는 강좌였는데 3시간이면 만든다는데.... pygame 을 처음 사용해보는 저는... ', '')
# ('파이썬강좌 이걸로 확실히!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222154953233', "싶은 파이썬강좌는 바로 '[특별할인] 파이썬 패키지' 입니다!! 패키지 강좌이기 때문에 기초부터 실무 강의까지 모두 포함되어 있습니다! 수강기간은 180일 수강료는 79... ", '')
# ('왕초보 파이썬 강좌 1.3 변수', 'https://blog.naver.com/estar009?Redirect=Log&logNo=222064971110', '또다시 이 왕초보 파이썬 강좌로 몇시간만에 돌아왔네요. 이번에 배울 것은... 재밌으신가요? 맞습니다. 프로그래밍은 재밌습니다. 오늘의 강좌는 여기까지. 그럼 스-바!', '')
# ('Stein 의 초보를 위한 파이썬 ( Python ) < 실전 강좌 > - 제 0... ', 'https://blog.naver.com/henry9487?Redirect=Log&logNo=221988309617', '제 블로그에서 파이썬 기본기 강좌를 잘 보고 계신가요 ? 파이썬 강좌 프로젝트를 시작한지 얼마 되지 않았지만, 많은 사람들이 찾아와서 봐주시네요. 정말 감사합니다.... ', '')
# ('[파이썬 강좌]데이터베이스 sqlite 테이블생성', 'https://blog.naver.com/nasu0210?Redirect=Log&logNo=221526337232', '[파이썬 강좌]데이터베이스 sqlite 테이블생성 파이썬으로 데이터베이스를 다루어 보겠습니다. 파이썬으로 여러종류의 데이터 베이스(오라클... ', '')
# ('파이썬 강좌 4 ) 변수', 'https://blog.naver.com/puleugo2?Redirect=Log&logNo=222238005540', 'A = 100 파이썬에서는 변수를 아주 쉽게 지정할 수 있습니다. 앞에서 수가 아닌... 많은 곳에도 사용할 수 있습니다. 다른 사용처는 다음 강좌에서 깊게 들어가겠습니다.', '')
# ("edwith 강좌 '모두를 위한 프로그래밍 : 파이썬을 이용한... ", 'https://blog.naver.com/dkrkvudghk?Redirect=Log&logNo=222094115845', '이 강좌에서 인상깊었던 것은 파이썬에도 클래스 개념이 있었다는 것이다. C... 공부해서 사용해봐야겠다. 모두를 위한 파이썬 강좌 중에 제일 보람찼던 강좌였다.', '')
# ('파이썬 강좌 - 파이썬(python) 시작', 'https://blog.naver.com/ahalinux?Redirect=Log&logNo=221390492962', '아래 동영상을 링크합니다. 천천히 보면서 준비해 보세요. 파이썬(python) 강좌 ① - 인강 안내 - 오리엔테이션 - 양주종의 코딩스쿨 즐겁게 공부하세요.', '')
# ('파이썬 강좌 번외편. 클로저(Closure)', 'https://exynoa.tistory.com/347', '다시 살펴보는 스코핑 룰(Scoping rule) 파이썬의 함수 강좌 에서 스코핑 룰을 살펴본 적이 있습니다. 이 강좌에서는 혼란을 피하기 위해 LGB... ', '')
# ('파이썬 인강 ☞ 데이터 분석을... 통계분석 데이터 기초 과정 강좌', 'https://blog.naver.com/beta700?Redirect=Log&logNo=221788408728', '2회차 파이썬 배우기 강좌에서는 아나콘다 설치방법에 대해 학습합니다. 3~4회에서는 통합개발툴 spyder와 jupyter notebook 기본 사용법에 대해 배웁니다. 5~8번째... ', '')
# ('파이썬강좌 겁내지말고 시작하세요!', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221433148776', '개설되어있어요 파이썬으로 입문을 한뒤에 자바나 C언어, PHP 같은 언어도 추가적으로 공부하기에도 좋은 사이트 입니다. 파이썬강좌만 묶어놓은 패키지강좌 입니다.... ', '')
# ('파이썬강좌 하나도 어렵지 않다!', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221388707896', '언제 어디서나, 시간이나 장소에 제약 없이 들을 수 있는 온라인 파이썬강좌와 함께라면 누구나 파이썬 정복이 가능하답니다! 파이썬의 기초부터 응용까지 한번에... ', '')
# ('파이썬강좌 알차게 들어봐요!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222096179423', '저는 [특별할인] 파이썬 패키지! 강좌를 추천 드려요~!! 패키지 파이썬강좌로 기초부터 실무 강의까지 포함되어 있습니다 수강기간은 180일이고 가격은 79,000원으로... ', '')
# ('파이썬강좌 어디에 있지?', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221411163547', '아이티동스쿨에서 인기강좌 베스트 5를 보니 1위부터 5위까지 파이썬으로... 저는 hit라고 써져있는 가장 인기있는 파이썬강좌를 선택했어요. Python(파이썬) 프로그래밍... ', '')
# ('파이썬(Python) 강좌 00 - Prologue', 'https://blog.naver.com/msj5826?Redirect=Log&logNo=221008309705', '일부로 파이썬 버전 2를 사용하는 곳도 있습니다. 이번 파이썬 강좌는 여기서 마치고 다음강좌는 파이썬을 설치하고 실행하는 방법에 대해 알아보도록 하겠습니다.', '')
# ('파이썬강좌 프로그래밍 배우고싶다면', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221348278171', '있는 강좌예요 홈페이지 메인에 있는 파이썬배너를 클릭하면 기초부터 응용까지의 파이썬강좌를 모아서 79,000원에 수강할 수 있는 패키지 강좌로 이동합니다.... ', '')
# ('파이썬 강좌 및 유용한 사이트 모음', 'https://blog.naver.com/koromoon?Redirect=Log&logNo=220578871433', '블로그에서 파이썬 강좌 http://blog.eairship.kr/category/%ED%94%84%EB%A1%9C%EA%B7... 요즘 파이썬 공부함. ㅠㅠ 아놔~~~ 강좌는 쉽고 한눈에 보기 편한 걸... ', '')
# ('파이썬강좌 패키지로 마스터하자!', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221288413576', '오늘은여러분과 파이썬에 대해 이야기를나눠보고 파이썬강좌와... 패키지 강좌를 가져왔습니다 바로 파이썬패키지인데요 180일이라는 넉넉한수강기간과 59,000원으로... ', '')
# ('파이썬(Python) 강좌 003 - 정수와 사칙 연산', 'https://blog.naver.com/ahalinux?Redirect=Log&logNo=221010383136', '파이썬(Python) 강좌 003 정수와 사칙 연산 코딩 파이썬(Python)... 양주종코딩스쿨 - 파이썬 강좌 >>> >>> print("양주종코딩스쿨... ', '')
# ('파이썬강좌 추천 해봅니다', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221298574112', '관련 강좌로 빅데이터 관련 강의가 인기가 많아요 파이썬강좌 추천 강의명은 파이썬 프로그래밍 제대로 배우기 part1 입니다. 총 25강동안 파이썬의 기초를 배울 수... ', '')
# ('파이썬강좌 후회없어요', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221257278009', '인기강좌 베스트5위 안에 항상 파이썬강좌가 있어서 쉽게 강의를 찾을 수 있어요. 사이트 위쪽에 강의검색 창에 파이썬이라고 검색해도 나옵니다. 빅데이터에... ', '')
# ('파이썬강좌 핵심포인트를 체크하자', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221173502951', '설명으로 파이썬 학습에 대한 흥미를 향상시켜줄 거랍니다~^^ 쉽게 배우는 Python 강의 더 알아볼까요? 파이썬강좌는 김정일 강사님께서 진행해주시구요 25강을 30일 동안... ', '')
# ('파이썬강좌 힘차게 달려볼까?', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221197558927', "위 사진 과 같이 R, 하둡, Scratch와 같은타 프로그래밍 언어 강좌와 함께파이썬강좌가 개설되어 있는 것, 다들 보이시죠~?~? 구체적으로, 아이티동스쿨에서는 '파이썬... ", '')
# ('파이썬 강좌 인강+교안으로 시작하자', 'https://blog.naver.com/hjchoi1500?Redirect=Log&logNo=221278925599', '안녕하세요 IT 메쌤입니다 파이썬 강좌 인강+교안으로 시작하자 포스팅할게요 빅데이터, AI등 머신러닝/딥러닝을 장착하는 신성장 동력분야에 기초가 되는 파이썬... ', '')
# ('파이썬강좌 기초와 응용을 한꺼번에!', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221327821446', '저는 아이티동스쿨에 마련된 모든 파이썬강좌를 180일간 들을 수 있는 파이썬 패키지를 통해 공부하시라고 추천해드리고 싶은데요. 언제 어디서나, 내가 원하는 시간과... ', '')
# ('파이썬 강좌 4 ) 변수', 'https://blog.naver.com/puleugo2?Redirect=Log&logNo=222238005540', 'A = 100 파이썬에서는 변수를 아주 쉽게 지정할 수 있습니다. 앞에서 수가 아닌... 많은 곳에도 사용할 수 있습니다. 다른 사용처는 다음 강좌에서 깊게 들어가겠습니다.', '')
# ("edwith 강좌 '모두를 위한 프로그래밍 : 파이썬을 이용한... ", 'https://blog.naver.com/dkrkvudghk?Redirect=Log&logNo=222094115845', '이 강좌에서 인상깊었던 것은 파이썬에도 클래스 개념이 있었다는 것이다. C... 공부해서 사용해봐야겠다. 모두를 위한 파이썬 강좌 중에 제일 보람찼던 강좌였다.', '')
# ('파이썬 강좌 - 파이썬(python) 시작', 'https://blog.naver.com/ahalinux?Redirect=Log&logNo=221390492962', '아래 동영상을 링크합니다. 천천히 보면서 준비해 보세요. 파이썬(python) 강좌 ① - 인강 안내 - 오리엔테이션 - 양주종의 코딩스쿨 즐겁게 공부하세요.', '')
# ('파이썬 강좌 번외편. 클로저(Closure)', 'https://exynoa.tistory.com/347', '다시 살펴보는 스코핑 룰(Scoping rule) 파이썬의 함수 강좌 에서 스코핑 룰을 살펴본 적이 있습니다. 이 강좌에서는 혼란을 피하기 위해 LGB... ', '')
# ('파이썬 인강 ☞ 데이터 분석을... 통계분석 데이터 기초 과정 강좌', 'https://blog.naver.com/beta700?Redirect=Log&logNo=221788408728', '2회차 파이썬 배우기 강좌에서는 아나콘다 설치방법에 대해 학습합니다. 3~4회에서는 통합개발툴 spyder와 jupyter notebook 기본 사용법에 대해 배웁니다. 5~8번째... ', '')
# ('파이썬강좌 겁내지말고 시작하세요!', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221433148776', '개설되어있어요 파이썬으로 입문을 한뒤에 자바나 C언어, PHP 같은 언어도 추가적으로 공부하기에도 좋은 사이트 입니다. 파이썬강좌만 묶어놓은 패키지강좌 입니다.... ', '')
# ('파이썬강좌 하나도 어렵지 않다!', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221388707896', '언제 어디서나, 시간이나 장소에 제약 없이 들을 수 있는 온라인 파이썬강좌와 함께라면 누구나 파이썬 정복이 가능하답니다! 파이썬의 기초부터 응용까지 한번에... ', '')
# ('파이썬강좌 알차게 들어봐요!', 'https://blog.naver.com/itsdongs?Redirect=Log&logNo=222096179423', '저는 [특별할인] 파이썬 패키지! 강좌를 추천 드려요~!! 패키지 파이썬강좌로 기초부터 실무 강의까지 포함되어 있습니다 수강기간은 180일이고 가격은 79,000원으로... ', '')
# ('파이썬강좌 어디에 있지?', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221411163547', '아이티동스쿨에서 인기강좌 베스트 5를 보니 1위부터 5위까지 파이썬으로... 저는 hit라고 써져있는 가장 인기있는 파이썬강좌를 선택했어요. Python(파이썬) 프로그래밍... ', '')
# ('파이썬(Python) 강좌 00 - Prologue', 'https://blog.naver.com/msj5826?Redirect=Log&logNo=221008309705', '일부로 파이썬 버전 2를 사용하는 곳도 있습니다. 이번 파이썬 강좌는 여기서 마치고 다음강좌는 파이썬을 설치하고 실행하는 방법에 대해 알아보도록 하겠습니다.', '')
# ('파이썬강좌 프로그래밍 배우고싶다면', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221348278171', '있는 강좌예요 홈페이지 메인에 있는 파이썬배너를 클릭하면 기초부터 응용까지의 파이썬강좌를 모아서 79,000원에 수강할 수 있는 패키지 강좌로 이동합니다.... ', '')
# ('파이썬 강좌 및 유용한 사이트 모음', 'https://blog.naver.com/koromoon?Redirect=Log&logNo=220578871433', '블로그에서 파이썬 강좌 http://blog.eairship.kr/category/%ED%94%84%EB%A1%9C%EA%B7... 요즘 파이썬 공부함. ㅠㅠ 아놔~~~ 강좌는 쉽고 한눈에 보기 편한 걸... ', '')
# ('파이썬강좌 패키지로 마스터하자!', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221288413576', '오늘은여러분과 파이썬에 대해 이야기를나눠보고 파이썬강좌와... 패키지 강좌를 가져왔습니다 바로 파이썬패키지인데요 180일이라는 넉넉한수강기간과 59,000원으로... ', '')
# ('파이썬(Python) 강좌 003 - 정수와 사칙 연산', 'https://blog.naver.com/ahalinux?Redirect=Log&logNo=221010383136', '파이썬(Python) 강좌 003 정수와 사칙 연산 코딩 파이썬(Python)... 양주종코딩스쿨 - 파이썬 강좌 >>> >>> print("양주종코딩스쿨... ', '')
# ('파이썬강좌 추천 해봅니다', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221298574112', '관련 강좌로 빅데이터 관련 강의가 인기가 많아요 파이썬강좌 추천 강의명은 파이썬 프로그래밍 제대로 배우기 part1 입니다. 총 25강동안 파이썬의 기초를 배울 수... ', '')
# ('파이썬강좌 후회없어요', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=221257278009', '인기강좌 베스트5위 안에 항상 파이썬강좌가 있어서 쉽게 강의를 찾을 수 있어요. 사이트 위쪽에 강의검색 창에 파이썬이라고 검색해도 나옵니다. 빅데이터에... ', '')
# ('파이썬강좌 핵심포인트를 체크하자', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221173502951', '설명으로 파이썬 학습에 대한 흥미를 향상시켜줄 거랍니다~^^ 쉽게 배우는 Python 강의 더 알아볼까요? 파이썬강좌는 김정일 강사님께서 진행해주시구요 25강을 30일 동안... ', '')
# ('파이썬강좌 힘차게 달려볼까?', 'https://blog.naver.com/skyktc?Redirect=Log&logNo=221197558927', "위 사진 과 같이 R, 하둡, Scratch와 같은타 프로그래밍 언어 강좌와 함께파이썬강좌가 개설되어 있는 것, 다들 보이시죠~?~? 구체적으로, 아이티동스쿨에서는 '파이썬... ", '')
# ('파이썬 강좌 인강+교안으로 시작하자', 'https://blog.naver.com/hjchoi1500?Redirect=Log&logNo=221278925599', '안녕하세요 IT 메쌤입니다 파이썬 강좌 인강+교안으로 시작하자 포스팅할게요 빅데이터, AI등 머신러닝/딥러닝을 장착하는 신성장 동력분야에 기초가 되는 파이썬... ', '')
# ('파이썬강좌 기초와 응용을 한꺼번에!', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221327821446', '저는 아이티동스쿨에 마련된 모든 파이썬강좌를 180일간 들을 수 있는 파이썬 패키지를 통해 공부하시라고 추천해드리고 싶은데요. 언제 어디서나, 내가 원하는 시간과... ', '')
# ('6월 18일 파이썬학원 기초 무료 강좌', 'https://blog.naver.com/unseschool?Redirect=Log&logNo=221296582469', '6월 18일 파이썬 기초 무료 강좌 안내 파이썬이란? 작년 파이썬 기초 세미나 표가 1시간내에 매진되었다고 합니다. 파이썬 강좌에 대한 관심도를 반영하는것같습니다.... ', '')
# ('파이썬강좌 실습을 통해 공부하자!', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221225079687', '따로 교재를 구매할 필요 없이 교안과 예제파일을 다운로드 받아 부담 없는 파이썬 학습이 가능한 파이썬강좌라고 하니 학원을 다니기에 이런저건 여건이 안되는... ', '')
# ('파이썬강좌 설명 good', 'https://blog.naver.com/thebenzecl?Redirect=Log&logNo=220913191037', '인기강좌 순서가 그때그때 달라지더라구요. 파이썬강좌는 프로그래밍... 59,000원이예요 파이썬 강좌 중 파이썬 제대로 배우기 강의에서는 기초적인 내용을 배워요... ', '')
# ('파이썬강좌 이젠 나도 프로그래밍 전문가!', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221151419064', '학원이나 강좌가 굉장히 많기 때문에 어디에서 어떻게 공부하는 것이 가장... 이미 많은 사람들이 아이티동스쿨의 파이썬강좌를 통해 파이썬에 대해 공부하고 있으니... ', '')
# ('파이썬 시작하기 추천 강좌. Udemy에서', 'https://blog.naver.com/ji_sung31?Redirect=Log&logNo=221167152135', '암튼 파이썬을 첫 시작하는 사람들에게는 매우 좋은 강좌인듯. 기초만 잡아 놓으면 그 이후는 알아서 찾아가며 할 수 있으니.... 유데미 파이썬 강좌 강력... ', '')
# ('자격증 인강 -cos파이썬 강의, 자바 자격증 강좌 cscul.com', 'https://blog.daum.net/comkid7/15178996', 'cosjava강좌 , cosjava인강 , cos강좌 , cos인강 , cos자바강의 , cos자바강좌 , cos자바인강 , cos파이썬강좌 , cos파이썬인강 씨스꿀 COS PRO 자바 강좌 (코스 프로 JAVA)... ', '')
# ('파이썬강좌,파이썬 독학 : 컴띵에서 인강듣기', 'https://blog.naver.com/soulmatebj?Redirect=Log&logNo=220765913699', '컴퓨터관련 강좌가 굉장히 많이 보유되어 있는 컴띵입니다. 컴퓨터 프로그램 전문... 이겨냅시다 파이썬강좌,파이썬 독학 : 컴띵에서 인강듣기 포스팅이였습니다. 위... ', '')
# ('파이썬강좌 패키지로 저렴하게 공부하세요!', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221018212813', '강좌와 얼마 차이도 안나니까 정말 부담없이 공부할 수 있으실 거에요! 이 파이썬강좌는 이론과 실무를 함께 공부하고싶은 분들이라면 권해드리고 싶어요 또한 파이썬... ', '')
# ('파이썬강좌 어디가 좋을까?', 'https://blog.naver.com/smujack?Redirect=Log&logNo=221059950094', '즐거운 수요일입니다~ 오늘은 파이썬강좌에 대해 알려드릴게요 파이썬은 프로그래밍 언어 중 하나로 쉽고 간결하여 초보자들이 이용하기 좋고 다양한 분야에 활용할 수... ', '')
# ('파이썬 강좌 듣기 좋은 사이트 (IT동스쿨)', 'https://blog.naver.com/armigar?Redirect=Log&logNo=220619948032', '실제로 인기 강좌 베스트 5 중 3개가 파이썬 강좌일 정도로 파이썬 강좌가 매우 인기를 얻고 있습니다. 저는 파이썬을 가지고 실제로 개발에 참여를 하고 있는... ', '')
