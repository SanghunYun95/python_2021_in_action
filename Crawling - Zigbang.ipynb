# %% [markdown]
# ## 수정 전 코드

# %%
import requests
from bs4 import BeautifulSoup
import json
import pprint

def get_bang(keyword):
    
    # 위도 경도
    url =f'https://apis.zigbang.com/search/all?q={keyword}&type=oneroom'
    r = requests.get(url)
    result = json.loads(r.text)
    if result['success']:
        lat = result['items'][0]['lat']
        lag = result['items'][0]['lag']
        
    # zoom level 기본 (6)에 따른 위치 범위값    실제로는 Daum map API를 사용하여야 함, 여기서는 대충 계산
    south = lat - 0.03370855171711
    north = lat + 0.0335695281371
    west = lng - 0.0319765406923
    east = lng + 0.0320013566581
    
    # id값 목록 가져오기
    url_ids = f'https://apis.zigbang.com/v3/items2?lat_sout={south}&lat_north={north}&lng_west={west}&lng_east={east}&room=[01,02,03,04,05]'
    r_ids = requests.get(url_ids)
    result_ids = json.loads(r_ids.text)
    item_ids = []
    for item in result_ids['list_items']:
        item_ids.append(item['simple_item']['item_id'])
        
    # id를 통해 가져온 detail infos
    url_detail = f'https://apis.zigbang.com/v3/items?detail=true&item_ids={item_ids[0:60]}'
    r_detail = requests.get(url_detail)
    result_detail = json.loads(r_detail.text)
    
    bang_lists = []
    for i in result_detail['items']:
        title = i['title']
        item = i['item']
        address1 = item['address1']
        address2 = item['address2']
        address3 = item['address3']
        deposit = item['deposit']
        rent = item['rent']
        size = item['size']
        size_m2 = item['size_m2']
        item_title = item['title']
        
        bang_lists.append(title, address1, address2, address3, deposit, rent, size, size_m2, item_title)
        
    return bang_lists

for i in get_bang('서울시 종로구'):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-1bdc5ff64854> in <module>
#      50     return bang_lists
#      51
# ---> 52 for i in get_bang('서울시 종로구'):
#      53     print(i)
#      54
#
# <ipython-input-2-1bdc5ff64854> in get_bang(keyword)
#       9     url =f'https://apis.zigbang.com/search/all?q={keyword}&type=oneroom'
#      10     r = requests.get(url)
# ---> 11     result = json.loads(r.text)
#      12     if result['success']:
#      13         lat = result['items'][0]['lat']
#
# ~\anaconda3\envs\inaction\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\envs\inaction\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\envs\inaction\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## 개정

# %%
'''
2020-01-29 직방 사이트 리뉴얼로 인해 내부 ajax 통신 방식 변경으로 인한 수정
기존에 사용하던 직방 내부의 api 는 사용되지 않습니다.
Geohash 를 사용하기 위해서

pip install geohash2 

라이브러리를 설치해야 합니다.
'''
import requests
import pprint
import geohash2

keyword = "대치동"

# 최초 검색어에 해당하는 검색어값의 자동완성 ajax 주소 입니다.
# 예를 들어 사이트에서 대치동을 입력하면 대치동, 르엘대치(아파트), 대치동더블유타워(오피스텔)... 등의 
# 검색 결과목록이 나오는데 이 값을 구해오는 주소 입니다.
url = "https://apis.zigbang.com/search?q={}".format(keyword)

req = requests.get(url)

# 실제 api 주소에서 json 형태로 리턴되기 때문에 json 형태로 값을 받습니다.
# json 형태로 받은 값은 사용하기도 편리합니다.
_json = req.json()

# api 상태코드가 200인 경우가 오류없이 동작되었다는 의미입니다.
if _json.get("code") == "200":
    # 위에서 말한대로 검색어에 해당하는 자동완성값은 여러개인데 
    # 그중에 맨 위에 [0] 번째 한가지에 대해서만 검색을 합니다.
    data = _json.get("items")[0]
    _description = data.get("description")
    _id = data.get("id")
    _lat = data.get("lat")
    _lng = data.get("lng")
    _zoom = data.get("zoom")

    # 기존코드와 현재 변경된 직방 페이지에서 가장 중요하게 변경된 점은
    # 기존에는 lat, lng 값을 구해서 임의로 적정 영역을 +, - 해서 
    # 지도의 사각형 영역을 구한다음에 그 영역에 대한 쿼리를 요청했었는데
    # 변경된 직방 사이트는 Geohash 를 사용하도록 변경되었습니다.
    # Geohash 에 대한 정보는 https://en.wikipedia.org/wiki/Geohash 를 참고하시기 바랍니다.
    # 맨위에 설명한데로 파이썬 geohash2 라이브러를 먼저 설치해야 합니다.
    # precision 정밀도를 5로 설정해야만 직방에서 사용하는 geohash 와 일치하는듯 보입니다.
    geohash = geohash2.encode(_lat, _lng, precision=5)

    # 위에서 구한 geohash 값을 아래의 api 로 호출하고 쿼리(전세 월세 등)를 넘겨주는 주소 입니다.
    url = "https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={}&rent_gteq=0&sales_type_in=전세%7C월세&service_type_eq=원룸".format(geohash)

    # 역시 json 형태로 값을 취합니다.
    _req_items = requests.get(url).json()

    # json 데이터에서 items 값만 저장합니다.
    # items 값은 실제 매물 데이터의 인덱스 값입니다.
    _items = _req_items.get("items")

    # 위에서 취한 json 형태의 items 목록을
    # 파이썬 리스트 형태로 저장합니다.
    item_ids = []
    for item in _items:
        item_ids.append(item.get("item_id"))

    # 위에서 저장한 list 의 100개만
    # items_ids 라는 키의 값으로 설정합니다.
    # 최종적으로 이 값을 직방 api 에 요청합니다.
    items = {"item_ids": item_ids[:100]}

    # 위에서 만든 items_ids: [매물인덱스] 를 아래 주소로 쿼리 한 후 json 형태로 받습니다.
    _results = requests.post('https://apis.zigbang.com/v2/items/list', data=items).json()

    # 최종 완성된 매물 결과는 items 안에 있습니다.
    datas = _results.get("items")

    # 매물 목록을 돌며 화면에 출력합니다.
    for d in datas:
        _address = "{} {}".format(d.get("address1"), d.get("address2"))
        if d.get("address3") is not None:
            _address += " {}".format(d.get("address3"))

        building_floor = d.get("building_floor")
        floor = d.get("floor")
        thumbnail = d.get("images_thumbnail")
        item_id = d.get("item_id")
        reg_date = d.get("reg_date")
        sales_type = d.get("sales_type")
        service_type = d.get("service_type")
        size_m2 = d.get("size_m2")
        title = d.get("title")
        deposit = d.get("deposit")
        rent = d.get("rent")

        # pprint.pprint(d)
        print("*" * 100)
        print("{} [{}]".format(title, item_id))
        print("보증금/월세: {}/{}".format(deposit, rent))
        print("건물층/매물층: {}/{}".format(building_floor, floor))
        print("등록일자: {}".format(reg_date))
        print("서비스형태/매물형태: {}/{}".format(service_type, sales_type))
        print("사이즈: {}".format(size_m2))
# Out:
# ****************************************************************************************************
# 삼성병원5분거리.대청역.수서역인근.여성환영 [26079602]
# 보증금/월세: 1000/50
# 건물층/매물층: 4/2
# 등록일자: 2021-02-17T14:38:14+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 26.45
# ****************************************************************************************************
# ◈ 저렴하고 넓은 원룸 ◈ 풀옵션 ◈ 치안 걱정 NO! [26032199]
# 보증금/월세: 5000/35
# 건물층/매물층: 5/4
# 등록일자: 2021-02-15T09:54:45+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 26.45
# ****************************************************************************************************
# 유러피안 스타일의 신축 투룸, 풀옵션, 주차기능 [25906889]
# 보증금/월세: 37000/0
# 건물층/매물층: 4/2
# 등록일자: 2021-02-03T12:08:44+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈:
09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# *삼성병원.대청역주변. [26032224]
# 보증금/월세: 1000/55
# 건물층/매물층: 2/2
# 등록일자: 2021-02-15T09:55:42+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 29.75
# ****************************************************************************************************
# 삼성병원 후문 인근 풀옵션 원룸 [25901241]
# 보증금/월세: 1000/47
# 건물층/매물층: 2/2
# 등록일자: 2021-02-02T22:05:55+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 🔴우리동네🔴신축 급 넓은 투룸🔴대출OK🔴 [25630070]
# 보증금/월세: 33000/0
# 건물층/매물층: 5/3
# 등록일자: 2021-02-17T17:36:18+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 55.59
# ****************************************************************************************************
# 삼성병원 인근 대로변 안전한 풀옵션 원룸 [26032767]
# 보증금/월세: 3000/50
# 건물층/매물층: 2/2
# 등록일자: 2021-02-15T10:10:30+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 23.14
# ****************************************************************************************************
# *대청역.삼성병원인근.복층.대출가능.수수료50%할인 [26032353]
# 보증금/월세: 40000/0
# 건물층/매물층: 6/5
# 등록일자: 2021-02-15T10:01:57+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 52.89
# ****************************************************************************************************
# *대청역.삼성병원5분.버스정류장앞.대출가능.수수료50%할인 [26032362]
# 보증금/월세: 45000/0
# 건물층/매물층: 6/4
# 등록일자: 2021-02-15T10:00:12+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 59.5
# ****************************************************************************************************
# *대청역.삼성병원5분.내진설계.대출가능.수수료50%할인* [26032390]
# 보증금/월세: 46000/0
# 건물층/매물층: 6/3
# 등록일자: 2021-02-15T10:01:06+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 49.35
# ****************************************************************************************************
# 🔴우리동네🔴넓은 풀옵션 원룸🔴 [25963280]
# 보증금/월세: 1600/66
# 건물층/매물층: 5/2
# 등록일자: 2021-02-06T17:39:41+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 23.58
# ****************************************************************************************************
# 🔴우리동네🔴깔끔한 테라스 1.5룸🔴 [26001544]
# 보증금/월세: 3000/50
# 건물층/매물층: 2/2
# 등록일자: 2021-02-09T17:22:12+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 🔴우리동네🔴단독주택 리모델링 2층 3룸 주차가능 [26001732]
# 보증금/월세: 20000/60
# 건물층/매물층: 2/2
# 등록일자: 2021-02-09T17:29:42+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 70.57
# ****************************************************************************************************
# 🔴우리동네🔴신축 복층형 투룸  풀옵션🔴대출ok🔴 [26001370]
# 보증금/월세: 33000/0
# 건물층/매물층: 4/4
# 등록일자: 2021-02-09T17:15:37+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 39.67
# ****************************************************************************************************
# 🔴우리동네🔴신축 1.5룸 풀옵션🔴대출OK🔴 [25758144]
# 보증금/월세: 26000/0
# 건물층/매물층: 4/1
# 등록일자: 2021-02-05T12:11:17+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 26.78
# ****************************************************************************************************
# 🔴우리동네🔴오픈형 원룸 풀옵션🔴대출OK🔴 [25758146]
# 보증금/월세: 24000/0
# 건물층/매물층: 4/1
# 등록일자: 2021-02-05T12:12:34+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 23.14
# ****************************************************************************************************
# 로맨틱한 스타일의 1.5룸, 골드 장식의 화장실 [25907136]
# 보증금/월세: 25000/0
# 건물층/매물층: 4/1
# 등록일자: 2021-02-03T12:17:24+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 23.14
# ****************************************************************************************************
# *신축.햇볕잘드는집.대청역5분거리.대출가능.수수료50%할인 [26032372]
# 보증금/월세: 28000/0
# 건물층/매물층: 4/3
# 등록일자: 2021-02-15T10:00:32+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 30.41
# ****************************************************************************************************
# 🔴일원동🔴주차 100%🔴반전세 신축급 3룸🔴 [25758172]
# 보증금/월세: 25000/60
# 건물층/매물층: 4/3
# 등록일자: 2021-02-05T12:40:15+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 40.74
# ****************************************************************************************************
# 🌈대청역3분🌈귀한전세🌈역세권🌈신혼부부에 딱!!🌈 [25781749]
# 보증금/월세: 33000/0
# 건물층/매물층: 4/2
# 등록일자: 2021-01-26T12:15:24+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 56.2
# ****************************************************************************************************
# 🔴우리동네🔴신축 급 넓은 투룸🔴대출OK🔴 [25981308]
# 보증금/월세: 31000/0
# 건물층/매물층: 4/3
# 등록일자: 2021-02-08T15:38:24+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 30.56
# ****************************************************************************************************
# * 신축빌라.대청역5분거리.삼성병원,대출가능.풀옵션* [26032191]
# 보증금/월세: 26000/0
# 건물층/매물층: 4/1
# 등록일자: 2021-02-15T09:54:28+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 29.75
# ****************************************************************************************************
# *대청역5분.풀옵션.채광좋음.드레스룸있음,수수료할인50%* [26032325]
# 보증금/월세: 32000/0
# 건물층/매물층: 4/2
# 등록일자: 2021-02-15T10:01:51+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 36.36
# ****************************************************************************************************
# *대청역5분 .풀옵션,삼성병원옆.수수료50%할인* [26032333]
# 보증금/월세: 32000/0
# 건물층/매물층: 4/2
# 등록일자: 2021-02-15T09:59:20+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 42.12
# ****************************************************************************************************
# *대청역.삼성병원5분거리 신축.풀옵션.채광좋음,수수료할인* [26032343]
# 보증금/월세: 32000/0
# 건물층/매물층: 4/2
# 등록일자: 2021-02-15T09:59:40+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 36.36
# ****************************************************************************************************
# *대청역.삼성병원5분거리.풀옵션.수수료50%할인.대출가능* [26032379]
# 보증금/월세: 32000/0
# 건물층/매물층: 4/3
# 등록일자: 2021-02-15T10:00:50+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 42.53
# ****************************************************************************************************
# 방2 삼성병원 대청역 인근 풀옵션 [25985166]
# 보증금/월세: 10000/55
# 건물층/매물층: 5/3
# 등록일자: 2021-02-08T17:28:08+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 36.36
# ****************************************************************************************************
# 🔴🆘강남최저가구해줘🆘🔴한티역 유일한 오피스텔! [26020331]
# 보증금/월세: 140/140
# 건물층/매물층: 8/고
# 등록일자: 2021-02-11T12:04:38+09:00
# 서비스형태/매물형태: 오피스텔/월세
# 사이즈: 52.89
# ****************************************************************************************************
# 💟한티역도보3분💟더블역세권/저렴/깔끔/넓은방💙 [25924367]
# 보증금/월세: 1000/48
# 건물층/매물층: 4/1
# 등록일자: 2021-02-17T01:46:16+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 33.06
# ****************************************************************************************************
# 🛑배치좋은 투룸/거실/베란다/주차🛑한티역한걸음🛑🛑 [25951626]
# 보증금/월세: 4000/85
# 건물층/매물층: 3/2
# 등록일자: 2021-02-11T17:27:43+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 49.59
# ****************************************************************************************************
# 🛑가격인하🛑대치동🛑전세🛑투룸🛑수리완료🛑 [26070212]
# 보증금/월세: 20000/35
# 건물층/매물층: 4/2
# 등록일자: 2021-02-16T19:59:42+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 56.2
# ****************************************************************************************************
# ❤신축급투룸❤빅사이즈❤풀옵션❤ [25839334]
# 보증금/월세: 31500/0
# 건물층/매물층: 5/4
# 등록일자: 2021-02-01T13:33:41+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 59.5
# ****************************************************************************************************
# 💝구조최강💝강력추천👍대출ok!💯%실매물❗가성비甲👍 [25950088]
# 보증금/월세: 31500/0
# 건물층/매물층: 5/4
# 등록일자: 2021-02-05T18:46:58+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 52.89
# ****************************************************************************************************
# 🌈도곡초 대치4동 주민센터 인근 신축급 맞벽 투룸 전세 [26051021]
# 보증금/월세: 31500/0
# 건물층/매물층: 5/4
# 등록일자: 2021-02-15T18:44:29+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 32.62
# ****************************************************************************************************
# && 대치동 한티역 5분거리 깔끔 투룸 [26102745]
# 보증금/월세: 33000/0
# 건물층/매물층: 5/2
# 등록일자: 2021-02-18T18:23:22+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 49.59
# ****************************************************************************************************
# 한티역 역세권 깔끔한 원룸입니다~! [26068924]
# 보증금/월세: 1000/90
# 건물층/매물층: 4/3
# 등록일자: 2021-02-16T18:38:49+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 21.42
# ****************************************************************************************************
# @@전속매물 한티역 지상층 사이즈 큰 최저가 분리형원룸@@ [26032489]
# 보증금/월세: 1000/50
# 건물층/매물층: 5/5
# 등록일자: 2021-02-15T10:03:37+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 33.06
# ****************************************************************************************************
# 🌈 대치4동 주민센터 학원가 인근 🌈 2종근린 원룸 [26050956]
# 보증금/월세: 3000/50
# 건물층/매물층: 6/4
# 등록일자: 2021-02-15T18:41:55+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 깔끔한 화이트톤 풀옵션 1인거주에 딱 치안,보안 모두 굿! [26102836]
# 보증금/월세: 3000/70
# 건물층/매물층: 6/5
# 등록일자: 2021-02-18T18:27:09+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 깔끔한 화이트톤 풀옵션 1인거주에 딱 치안,보안 모두 굿! [26102962]
# 보증금/월세: 4000/65
# 건물층/매물층: 6/5
# 등록일자: 2021-02-18T18:32:01+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 깔끔한 화이트톤 풀옵션 1인거주에 딱 치안,보안 모두 굿! [26103024]
# 보증금/월세: 5000/60
# 건물층/매물층: 6/5
# 등록일자: 2021-02-18T18:34:38+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 깔끔한 화이트톤 풀옵션 1인거주에 딱 치안,보안 모두 굿! [26103064]
# 보증금/월세: 3000/50
# 건물층/매물층: 6/4
# 등록일자: 2021-02-18T18:37:23+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 깔끔한 화이트톤 풀옵션 1인거주에 딱 치안,보안 모두 굿! [26103120]
# 보증금/월세: 2000/55
# 건물층/매물층: 6/4
# 등록일자: 2021-02-18T18:39:54+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 깔끔한 화이트톤 풀옵션 1인거주에 딱 치안,보안 모두 굿! [26103211]
# 보증금/월세: 3000/50
# 건물층/매물층: 6/4
# 등록일자: 2021-02-18T18:43:46+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 깔끔한 화이트톤 풀옵션 1인거주에 딱 치안,보안 모두 굿! [26103341]
# 보증금/월세: 3000/50
# 건물층/매물층: 6/4
# 등록일자: 2021-02-18T18:49:29+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 깔끔한 화이트톤 풀옵션 1인거주에 딱 치안,보안 모두 굿! [26103373]
# 보증금/월세: 3000/50
# 건물층/매물층: 6/4
# 등록일자: 2021-02-18T18:51:02+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 19.83
# ****************************************************************************************************
# 💓New.개꿀집!💓특대형 2룸💓올리모델링💓 [25896676]
# 보증금/월세: 1500/110
# 건물층/매물층: 4/2
# 등록일자: 2021-02-03T14:45:01+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 60.17
# ****************************************************************************************************
# 올리모델링4룸2욕실✅대형평수✅교통발달✅은마아파트앞✅학군최고 [25864800]
# 보증금/월세: 120000/50
# 건물층/매물층: 4/4
# 등록일자: 2021-02-01T11:08:40+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 111.26
# ****************************************************************************************************
# ★저렴한 분리형 전세 [26099297]
# 보증금/월세: 25000/0
# 건물층/매물층: 5/5
# 등록일자: 2021-02-18T16:21:26+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 29.75
# ****************************************************************************************************
# ♥대치동 금액, 사이즈 좋은 투룸 월세♥애견가능♥ [26076149]
# 보증금/월세: 2000/80
# 건물층/매물층: 3/1
# 등록일자: 2021-02-17T12:06:18+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 62.81
# ****************************************************************************************************
# 은마사거리 인접 큰원룸 옵션있슴 보증금증감이 가능 실사진임 [25705426]
# 보증금/월세: 8000/40
# 건물층/매물층: 3/2
# 등록일자: 2021-01-20T19:28:21+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 33.06
# ****************************************************************************************************
# @@ 대출가능  학원가 지상층 최저가 반전세 원룸 @@ [25919880]
# 보증금/월세: 10000/30
# 건물층/매물층: 3/2
# 등록일자: 2021-02-04T12:38:29+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 26.45
# ****************************************************************************************************
# @@ 한티역부근 지상층 최저가 풀옵션원룸 @@ [25906829]
# 보증금/월세: 3000/50
# 건물층/매물층: 3/3
# 등록일자: 2021-02-03T17:14:05+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 23.14
# ****************************************************************************************************
# @@ 전속매물 한티역부근 지상층 최저가 반전세 쓰리룸 @@ [26078660]
# 보증금/월세: 10000/60
# 건물층/매물층: 3/2
# 등록일자: 2021-02-17T14:00:32+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 62.81
# ****************************************************************************************************
# @@ 무융자 전속매물 한티역 귀한 쓰리룸 전세 @@ [26078849]
# 보증금/월세: 27000/0
# 건물층/매물층: 3/1
# 등록일자: 2021-02-17T14:07:16+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 62.81
# ****************************************************************************************************
# 🌞채광Good🌞남향 분리형원룸 🚘주차가능 [26043819]
# 보증금/월세: 1000/60
# 건물층/매물층: 3/2
# 등록일자: 2021-02-15T14:59:51+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 23.14
# ****************************************************************************************************
# ✨깔끔한 거실맞벽나오는 귀한매물입니다✨ [25877506]
# 보증금/월세: 21000/40
# 건물층/매물층: 3/2
# 등록일자: 2021-02-01T17:31:47+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 66.12
# ****************************************************************************************************
# 🌈대치4동 도곡초 인근 아파트형 2베이가성비 반전세 투룸 [26051032]
# 보증금/월세: 21000/30
# 건물층/매물층: 3/2
# 등록일자: 2021-02-16T18:29:22+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 62.81
# ****************************************************************************************************
# 💖떴습니다💖귀한투룸전세💖거실넓어요💖융자無💖대출가능 [26067396]
# 보증금/월세: 21000/0
# 건물층/매물층: 3/2
# 등록일자: 2021-02-16T17:40:22+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 56.2
# ****************************************************************************************************
# #반려견 가능 #넑은 맞벽 투룸 #올 수리 #1.5층 [26047690]
# 보증금/월세: 2000/75
# 건물층/매물층: 1/1
# 등록일자: 2021-02-15T16:55:42+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 50
# ****************************************************************************************************
# ♡남향.전세자금대출가능♡분리형원룸♡아주 깨끗함♡ [25990265]
# 보증금/월세: 11000/0
# 건물층/매물층: 3/2
# 등록일자: 2021-02-09T13:05:32+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 29.75
# ****************************************************************************************************
# 투룸 수리완료 호실 즉시입주가능 [25893283]
# 보증금/월세: 28000/0
# 건물층/매물층: 4/2
# 등록일자: 2021-02-10T09:02:48+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 49.59
# ****************************************************************************************************
# 📌깔끔하고넓은투룸📌은마아파트사거리📌 [25941718]
# 보증금/월세: 5000/140
# 건물층/매물층: 5/3
# 등록일자: 2021-02-05T13:03:11+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 54.55
# ****************************************************************************************************
# 📌수험생,직장인1-2인거주에딱좋은풀옵션📌 [25905218]
# 보증금/월세: 2000/110
# 건물층/매물층: 5/3
# 등록일자: 2021-02-03T11:21:58+09:00
# 서비스형태/매물형태: 빌라/월세
# 사이즈: 39.6
# ****************************************************************************************************
# 옥탑낭만★오늘나온방!★100% 실매물★ [25936959]
# 보증금/월세: 12000/0
# 건물층/매물층: 5/5
# 등록일자: 2021-02-05T10:03:26+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 26.45
# ****************************************************************************************************
# @@ 전세가능 한티역5분거리 지상층 반전세 원룸 @@ [26059759]
# 보증금/월세: 15000/0
# 건물층/매물층: 5/5
# 등록일자: 2021-02-16T13:09:00+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 23.14
# ****************************************************************************************************
# 빅테라스 남향 채광굿! 원룸 [26055985]
# 보증금/월세: 12000/0
# 건물층/매물층: 5/5
# 등록일자: 2021-02-16T11:00:24+09:00
# 서비스형태/매물형태: 원룸/전세
# 사이즈: 69.42
# ****************************************************************************************************
# 💟대치동초저렴💟보증금조정/대출가능💙넓은평수/저렴💙 [25789240]
# 보증금/월세: 2000/39
# 건물층/매물층: 4/1
# 등록일자: 2021-02-17T01:45:45+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 33.06
# ****************************************************************************************************
# 💗도곡초인근신축💗편리한주차공간 깔끔한실내공간💗 [25662886]
# 보증금/월세: 1500/140
# 건물층/매물층: 5/3
# 등록일자: 2021-02-15T13:38:13+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 33.06
# ****************************************************************************************************
# 📌전세자금대출가능📌은마아파트사거리📌 [25942020]
# 보증금/월세: 32000/0
# 건물층/매물층: 5/3
# 등록일자: 2021-02-05T13:30:28+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 44.89
# ****************************************************************************************************
# 대치동 귀한 투룸전세 [25993602]
# 보증금/월세: 32000/0
# 건물층/매물층: 4/3
# 등록일자: 2021-02-10T09:00:47+09:00
# 서비스형태/매물형태: 빌라/전세
# 사이즈: 50.05
